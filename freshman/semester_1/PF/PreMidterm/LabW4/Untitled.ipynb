# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 1000
x = np.random.uniform(0, 40, n)
plt.plot(x)

# %%
plt.boxplot(x)
plt.xlabel("X")
plt.show()

# %%
y = np.random.uniform(0,30,n)
is_grow = np.array(x-2 * y+10 > 0, dtype=int)
# is_grow

# %%
plt.scatter(x, y, c=is_grow, s=50, edgecolor='k',
           cmap=plt.cm.summer)

# %%
a,b,c = 3, -10, 220
predict_is_grow = np.array(a*x + b*y + c > 0, dtype=int)
check_true_prediction = np.array(predict_is_grow==is_grow, dtype=int)
# check_true_prediction

# %%
x_line = np.array([0,40])
y_line =
# Out:
#   Input In [1]
#     y_line =
#              ^
# SyntaxError: invalid syntax

# %%
import numpy as np
from itertools import permutations as pt

# %%
b = {1,2,{1},{2}, {1,2}}
b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 b = {1,2,{1},{2}, {1,2}}
#       2 b
#
# TypeError: unhashable type: 'set'

# %%
b = {1,2,"a", "b", "c"}
b
# Out:
# {1, 2, 'a', 'b', 'c'}

# %%
list(pt(b))
# Out:
# [('a', 'c', 1, 2, 'b'),
#  ('a', 'c', 1, 'b', 2),
#  ('a', 'c', 2, 1, 'b'),
#  ('a', 'c', 2, 'b', 1),
#  ('a', 'c', 'b', 1, 2),
#  ('a', 'c', 'b', 2, 1),
#  ('a', 1, 'c', 2, 'b'),
#  ('a', 1, 'c', 'b', 2),
#  ('a', 1, 2, 'c', 'b'),
#  ('a', 1, 2, 'b', 'c'),
#  ('a', 1, 'b', 'c', 2),
#  ('a', 1, 'b', 2, 'c'),
#  ('a', 2, 'c', 1, 'b'),
#  ('a', 2, 'c', 'b', 1),
#  ('a', 2, 1, 'c', 'b'),
#  ('a', 2, 1, 'b', 'c'),
#  ('a', 2, 'b', 'c', 1),
#  ('a', 2, 'b', 1, 'c'),
#  ('a', 'b', 'c', 1, 2),
#  ('a', 'b', 'c', 2, 1),
#  ('a', 'b', 1, 'c', 2),
#  ('a', 'b', 1, 2, 'c'),
#  ('a', 'b', 2, 'c', 1),
#  ('a', 'b', 2, 1, 'c'),
#  ('c', 'a', 1, 2, 'b'),
#  ('c', 'a', 1, 'b', 2),
#  ('c', 'a', 2, 1, 'b'),
#  ('c', 'a', 2, 'b', 1),
#  ('c', 'a', 'b', 1, 2),
#  ('c', 'a', 'b', 2, 1),
#  ('c', 1, 'a', 2, 'b'),
#  ('c', 1, 'a', 'b', 2),
#  ('c', 1, 2, 'a', 'b'),
#  ('c', 1, 2, 'b', 'a'),
#  ('c', 1, 'b', 'a', 2),
#  ('c', 1, 'b', 2, 'a'),
#  ('c', 2, 'a', 1, 'b'),
#  ('c', 2, 'a', 'b', 1),
# ...

# %%
from itertools import chain, combinations

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
list(powerset(b))
# Out:
# [(),
#  ('a',),
#  ('c',),
#  (1,),
#  (2,),
#  ('b',),
#  ('a', 'c'),
#  ('a', 1),
#  ('a', 2),
#  ('a', 'b'),
#  ('c', 1),
#  ('c', 2),
#  ('c', 'b'),
#  (1, 2),
#  (1, 'b'),
#  (2, 'b'),
#  ('a', 'c', 1),
#  ('a', 'c', 2),
#  ('a', 'c', 'b'),
#  ('a', 1, 2),
#  ('a', 1, 'b'),
#  ('a', 2, 'b'),
#  ('c', 1, 2),
#  ('c', 1, 'b'),
#  ('c', 2, 'b'),
#  (1, 2, 'b'),
#  ('a', 'c', 1, 2),
#  ('a', 'c', 1, 'b'),
#  ('a', 'c', 2, 'b'),
#  ('a', 1, 2, 'b'),
#  ('c', 1, 2, 'b'),
#  ('a', 'c', 1, 2, 'b')]
